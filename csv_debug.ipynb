# %%
import pandas as pd

df = pd.read_csv("csv/musiclist.csv")

# %%
df[df.isnull().any(axis=1)]["artist_name"].fillna("")
# Out:
# 5
# 39
# 55
# 56
# 57
#       ..
# 448
# 449
# 450
# 451
# 452
# Name: artist_name, Length: 109, dtype: object

# %%
df[df["artist_name"] == "corok-Bb"]
# Out:
#         album_id                                         album_name  \
# 439    603189296                                  oriental breeze 2
# 535   1481385977         exp.37「TDL. BEST -2017.09~2018.08-」- 10月EP
# 552   2986436682                                             ワルイベイス
# 555   2986436682                                             ワルイベイス
# 618   3334961036                           音楽ゲーム風アルバム「BEAT MISSION」
# 622   3939294824                          exp.32「REWIND 2017」- 3月EP
# 626   3939294824                          exp.32「REWIND 2017」- 3月EP
# 653   3740449486                        Hello, Dance and Groovement
# 694    112797380                          Twin paradoX 3 -Electric-
# 708    681856806         exp.27「TDL. BEST -2016.09~2017.08-」- 10月EP
# 712    681856806         exp.27「TDL. BEST -2016.09~2017.08-」- 10月EP
# 716    681856806         exp.27「TDL. BEST -2016.09~2017.08-」- 10月EP
# 748   2285288902                               Intersect the Future
# ...
